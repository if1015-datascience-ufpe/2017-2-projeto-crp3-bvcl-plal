# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests as rq

# %%
url = 'https://www.basketball-reference.com/'
req = rq.get(url)
page = BeautifulSoup(req.text, 'html.parser')
print(page)
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" data-root="/home/bbr/build" data-version="klecko-" itemscope="" itemtype="https://schema.org/WebSite" lang="en">
# <head id="suppress_all_ads">
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport">
# <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201711221" rel="dns-prefetch"/>
# <!-- no:cookie fast load the css.           -->
# <link crossorigin="" href="https://d2p3bygnnzw9w3.cloudfront.net" rel="preconnect"/>
# <link crossorigin="" href="https://d2cwpp38twqe55.cloudfront.net" rel="preconnect"/>
# <style>html,body{margin:0;padding:0;font:14px/1.25 "Helvetica Neue",helvetica,arial,sans-serif;color:#000}body{position:relative;background:#c9cbcd;z-index:0;-webkit-text-size-adjust:none;-moz-text-size-adjust:none;-ms-text-size-adjust:none}a img{border:0}ul,li,ol{margin:0;padding:0;list-style-type:none}table th,table td{border:0}iframe{max-width:100%}code{background:#eee}a,button,input,select,textarea,label,summary{touch-action:manipulation;-ms-touch-action:manipulation}::selection{background:#ff0;text-shadow:none}html.no-js .hasmore,html.no-js .js,html.js .no-js,html.no-js button,html.is_build .hide_build,html.is_dev .hide_dev,html.is_live .hide_live{display:none!important}.js-select{visibility:hidden}a[href]{color:#34d}a[href]:visited{color:#848}a[href]:hover{color:#5E44B3}a[href]:active{color:#b12}a[href^="tel:"]:before{content:"\260E";display:inline-block;margin-right:0}a[href^="mailto:"]:before{content:"\2709";display:inline-block;margin-right:0}.icon_group a[href^="tel:"]:before,.icon_group a[href^="mailto:"]:before{content:""}.screen_only{display:initial}.user_logged_in .not_logged_in,.logged_in,.sr_cpi_control,.print_only{display:none}#perflog,#modernizr,.user_logged_in .logged_in{display:block}h2{color:#000;margin-bottom:5px;font-size:1.5em}img.right{float:right;margin:0 0 5px 5px}img.left{float:left;margin:0 15px 15px 0}sup{font-size:.75em;position:relative;top:-0.4em;vertical-align:baseline}#wrap{width:100%;background:#fff;position:relative}#wrap>div,#wrap>ul{width:100%;position:relative;clear:both}.hidden,#content .hidden,.gutterad,.more,.print_only,#warnings.hide,#nag_devs{display:none}#inner_nav.hidden{visibility:hidden}.float_wrap{overflow:hidden}#header{overflow:visible;background:#efeeed;border-bottom:3px solid #f8951d}#header img{height:25px;float:left;padding:8px 0 8px 2%;max-width:71%;max-width:calc(95% - 80px)}#header #nav_trigger{display:block;cursor:pointer;float:right;padding:7px 2% 7px 1%;height:30px}#header #nav_trigger a{color:#f8951d;font-size:20px;font-weight:bold;text-decoration:none;display:inline-block}#header #nav_trigger a:before{color:#f8951d;content:"\2630 ";font-weight:normal}#header #nav{display:none;clear:both;width:88%;background:#fff;padding:7px 6% 0;border-bottom:3px solid #f8951d;border-top:3px solid #f8951d;overflow:hidden;font-size:12px}#header #nav .usertools{font-weight:bold;font-size:12px;margin:0 0 4px;padding:7px 6% 0;border-top:1px solid #c9cbcd}#header #nav .breadcrumbs{font-size:12px;padding:7px 6%;border-top:1px solid #c9cbcd}#header #main_nav{color:#454340;overflow:hidden}#header #main_nav>li{border-top:1px solid #c9cbcd}#header #main_nav>li:first-child{border-top:none}#header #main_nav>li>a{display:block;padding:8px 0 8px 6%;font-weight:bold;text-decoration:none;font-size:1.4em}html.no-touchevents #header #main_nav>li:active{background-color:#454340}#header #main_nav>li:active>a{color:#efeeed}#header #main_nav li.current{background-color:#f8951d}#header #main_nav li.current>a{color:#efeeed}#header #nav_trigger.open{background:#f8951d}#header #nav_trigger.open a{color:#fff}#header #nav_trigger.open a:before{color:#fff}#header #nav.open{display:block}#header #main_nav .nm{display:none}#header .social{margin:15px 0;display:none}#header.open_search{margin-bottom:50px}#header #subnav{display:none}#header .search{margin-top:10px;clear:both;padding:0 2% 6px}#header .search input,#header .search input:active,#header .search input:focus{height:32px;font-size:20px}.search input[type="search"]{padding:4px 5px;border:#747678 1px solid;width:73%;margin-right:2%}.search input[type="search"].prefilled{background-color:#ffa}.search input[type="submit"]{float:right;background:#f8951d;color:white;border:1px solid #747678;padding:0;border-radius:5px;height:24px;width:25%;width:calc(25% 0 2px)}.search input[type="submit"]:hover{text-decoration:underline}.search input[type="submit"]:active{background-color:#454340}.search .ac-outline{width:73%;margin-right:2%}.search .ac-outline input[type=" ...
# <link as="style" crossorigin="" href="https://d2p3bygnnzw9w3.cloudfront.net/req/201711221/css/bbr/sr-min.css" onload="this.rel='stylesheet'" rel="preload"/>
# <noscript><link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201711221/css/bbr/sr-min.css" rel="stylesheet" type="text/css"/></noscript>
# <link as="script" crossorigin="" href="https://d2p3bygnnzw9w3.cloudfront.net/req/201711221/js/bbr/sr-min.js" rel="preload"/>
# <link as="fetch" crossorigin="" href="https://d2p3bygnnzw9w3.cloudfront.net/req/201711221/icons/sr_icons-min.svg?bbr" rel="preload"/>
# <link as="fetch" crossorigin="" href="https://d2cwpp38twqe55.cloudfront.net/short/inc/main_nav_menu.json" rel="preload"/>
# <link as="image" crossorigin="" href="https://d2p3bygnnzw9w3.cloudfront.net/req/201604190/images/chosen-sprite.png" rel="preload"/>
# <link crossorigin="" href="https://www.google-analytics.com" rel="preconnect"/>
# <link crossorigin="" href="https://www.googletagservices.com" rel="preconnect"/>
# <script class="allowed">var sr_is_production = true;
# function vjs_ready(e){"loading"!=document.readyState?e():document.addEventListener("DOMContentLoaded",e)}var log_performance=!1,is_new_jscss_version=!1,sr_detect_operaMini=navigator.userAgent.indexOf("Opera Mini")>-1;sr_detect_operaMini&&((el=document.querySelector("html")).className=el.className.concat(" operamini"));var sr_detect_firefox=navigator.userAgent.indexOf("Firefox")>-1;sr_detect_firefox&&((el=document.querySelector("html")).className=el.className.concat(" firefox"));var sr_detect_firefoxMobile=navigator.userAgent.indexOf("Firefox")>-1&&(navigator.userAgent.indexOf("Mobile")>-1||navigator.userAgent.indexOf("Tablet")>-1);sr_detect_firefoxMobile&&((el=document.querySelector("html")).className=el.className.concat(" firefox-mobile"));var sr_detect_ie=function(){var e=window.navigator.userAgent;if(e.indexOf("Trident/7.0")>0)return 11;if(e.indexOf("Trident/6.0")>0)return 10;if(e.indexOf("Trident/5.0")>0)return 9;for(var t=3,n=document.createElement("div"),r=n.getElementsByTagName("i");n.innerHTML="\x3c!--[if gt IE "+ ++t+"]><i></i><![endif]--\x3e",r[0];);return t>4&&t}(),sr_detect_edge=!sr_detect_ie&&!!window.StyleMedia,sr_detect_safari=/Safari/.test(navigator.userAgent)&&/Apple Computer/.test(navigator.vendor),el=document.querySelector("html"),className="no-js";el.classList?el.classList.remove(className):el.className=el.className.replace(new RegExp("(^|\\b)"+className.split(" ").join("|")+"(\\b|)","gi")," "),el.className=el.className.concat(" js"),function(e,t,n){function r(e,t){return typeof e===t}function o(){return"function"!=typeof t.createElement?t.createElement(arguments[0]):x?t.createElementNS.call(t,"http://www.w3.org/2000/svg",arguments[0]):t.createElement.apply(t,arguments)}function i(){var e=t.body;return e||(e=o(x?"svg":"body"),e.fake=!0),e}function a(e,n,r,a){var s,l,c,d,u="modernizr",f=o("div"),m=i();if(parseInt(r,10))for(;r--;)c=o("div"),c.id=a?a[r]:u+(r+1),f.appendChild(c);return s=o("style"),s.type="text/css",s.id="s"+u,(m.fake?m:f).appendChild(s),m.appendChild(f),s.styleSheet?s.styleSheet.cssText=e:s.appendChild(t.createTextNode(e)),f.id=u,m.fake&&(m.style.background="",m.style.overflow="hidden",d=M.style.overflow,M.style.overflow="hidden",M.appendChild(m)),l=n(f,e),m.fake?(m.parentNode.removeChild(m),M.style.overflow=d,M.offsetHeight):f.parentNode.removeChild(f),!!l}function s(e){return e.replace(/([a-z])-([a-z])/g,function(e,t,n){return t+n.toUpperCase()}).replace(/^-/,"")}function l(e,t){return!!~(""+e).indexOf(t)}function c(e,t){return function(){return e.apply(t,arguments)}}function d(e,t,n){var o;for(var i in e)if(e[i]in t)return!1===n?e[i]:(o=t[e[i]],r(o,"function")?c(o,n||t):o);return!1}function u(e){return e.replace(/([A-Z])/g,function(e,t){return"-"+t.toLowerCase()}).replace(/^ms-/,"-ms-")}function f(t,n,r){var o;if("getComputedStyle"in e){o=getComputedStyle.call(e,t,n);var i=e.console;null!==o?r&&(o=o.getPropertyValue(r)):i&&i[i.error?"error":"log"].call(i,"getComputedStyle returning null, its possible modernizr test results are inaccurate")}else o=!n&&t.currentStyle&&t.currentStyle[r];return o}function m(t,r){var o=t.length;if("CSS"in e&&"supports"in e.CSS){for(;o--;)if(e.CSS.supports(u(t[o]),r))return!0;return!1}if("CSSSupportsRule"in e){for(var i=[];o--;)i.push("("+u(t[o])+":"+r+")");return i=i.join(" or "),a("@supports ("+i+") { #modernizr { position: absolute; } }",function(e){return"absolute"==f(e,null,"position")})}return n}function p(e,t,i,a){function c(){u&&(delete k.style,delete k.modElem)}if(a=!r(a,"undefined")&&a,!r(i,"undefined")){var d=m(e,i);if(!r(d,"undefined"))return d}for(var u,f,p,v,h,g=["modernizr","tspan","samp"];!k.style&&g.length;)u=!0,k.modElem=o(g.shift()),k.style=k.modElem.style;for(p=e.length,f=0;p>f;f++)if(v=e[f],h=k.style[v],l(v,"-")&&(v=s(v)),k.style[v]!==n){if(a||r(i,"undefined"))return c(),"pfx"!=t||v;try{k.style[v]=i}catch(e){}if(k.style[v]!=h)return c(),"pfx"!=t||v}return c(),!1}function v(e,t,n,o,i){var a=e.charAt(0).toUpperCase()+e.slice(1),s=(e+" "+N.join( ...
#
# </script>
# <script>
# if (Modernizr.is_modern) { loadJS( "https://d2p3bygnnzw9w3.cloudfront.net/req/201711221/js/bbr/sr-min.js"     , function() { vjs_ready(sr_fire_js); }); }
# else                     { loadJS( "https://d2p3bygnnzw9w3.cloudfront.net/req/201711221/js/bbr/sr-basic-min.js", function() { vjs_ready(sr_fire_js); }); }
# </script>
# <script>sr_utilities_js_loader.push(function() { vjs_createCookie('srcssfull', 'yes', 0.5 )});</script>
# <title>Basketball Statistics and History | Basketball-Reference.com</title>
# <meta content="True" name="HandheldFriendly">
# <meta content="build_home_page.pl" name="generated-by"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="#4d4438" name="theme-color"/>
# <meta content="#4d4438" name="msapplication-navbutton-color"/>
# <meta content="#4d4438" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="basketball, index, statistics, history" name="keywords"/>
# <link href="https://www.basketball-reference.com" rel="canonical">
# <meta content="https://www.basketball-reference.com" itemprop="url"/>
# <meta content="Basketball Reference" itemprop="name"/>
# <meta content="BkRef" itemprop="alternateName"/>
# <meta content="Basketball Statistics and History" name="Description"/>
# <meta content="" property="fb:app_id"/>
# <meta content="https://www.basketball-reference.com" property="og:url"/>
# <meta content="Basketball Statistics and History | Basketball-Reference.com" property="og:title"/>
# <meta content="Basketball-Reference.com" property="og:site_name"/>
# <meta content="    article" property="og:type">
# <meta content="Basketball Statistics and History" property="og:description"/>
# <meta content="https://d2p3bygnnzw9w3.cloudfront.net/req/201711221/favicons/bbr/apple-touch-icon-228x228-precomposed.png" property="og:image"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@bball_ref" name="twitter:site"/>
# <meta content="@bball_ref" name="twitter:creator"/>
# <meta content="https://d2p3bygnnzw9w3.cloudfront.net/req/201711221/favicons/bbr/apple-touch-icon-228x228-precomposed.png" property="twitter:image"/>
# <meta content="Basketball-Reference.com" name="twitter:domain"/>
# <meta content="unsafe-url" name="referrer"/>
# <!-- tiles, touch, favicons -->
# <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201711221/favicons/bbr/apple-touch-icon-192x192-precomposed.png" rel="icon" sizes="192x192"/>
# <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201711221/favicons/bbr/apple-touch-icon-228x228-precomposed.png" rel="apple-touch-icon" sizes="228x228"/>
# <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201711221/favicons/bbr/apple-touch-icon-195x195-precomposed.png" rel="apple-touch-icon" sizes="195x195"/>
# <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201711221/favicons/bbr/apple-touch-icon-180x180-precomposed.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201711221/favicons/bbr/apple-touch-icon-152x152-precomposed.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201711221/favicons/bbr/apple-touch-icon-144x144-precomposed.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201711221/favicons/bbr/apple-touch-icon-128x128-precomposed.png" rel="apple-touch-icon" sizes="128x128"/>
# <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201711221/favicons/bbr/apple-touch-icon-120x120-precomposed.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201711221/favicons/bbr/apple-touch-icon-114x114-precomposed.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201711221/favicons/bbr/apple-touch-icon-76x76-precomposed.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201711221/favicons/bbr/apple-touch-icon-72x72-precomposed.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201711221/favicons/bbr/apple-touch-icon-57x57-precomposed.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201711221/favicons/bbr/favicon-32.png" rel="icon" sizes="32x32"/>
# <!--[if IE]>
#     <link rel="shortcut icon"                                href="https://d2p3bygnnzw9w3.cloudfront.net/req/201711221/favicons/bbr/favicon.ico"><![endif]-->
# <meta content="#905500" name="msapplication-TileColor">
# <meta content="https://d2p3bygnnzw9w3.cloudfront.net/req/201711221/favicons/bbr/ms-tile-144.png" name="msapplication-TileImage">
# <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201711221/opensearch/opensearch-bbr.xml" rel="search" title=" Player and Team Search" type="application/opensearchdescription+xml"/>
# </meta></meta></meta></link></meta></meta></head>
# <body class="bbr">
# <div id="wrap">
# <div id="header" role="banner">
# <ul id="subnav">
# <li><a href="https://www.sports-reference.com/"><svg height="15px" width="20px"><use xlink:href="#ic-sr-pennant"></use></svg> Sports Reference</a></li>
# <li><a href="https://www.baseball-reference.com/">Baseball</a></li>
# <li><a href="https://www.pro-football-reference.com/">Football</a> <a href="https://www.sports-reference.com/cfb/">(college)</a></li>
# <li class="current"><a href="https://www.basketball-reference.com/">Basketball</a> <a href="https://www.sports-reference.com/cbb/">(college)</a></li>
# <li><a href="https://www.hockey-reference.com/">Hockey</a></li>
# <li><a href="https://fbref.com/">Soccer</a></li>
# <li><a href="https://www.sports-reference.com/blog/">Blog</a></li>
# <li><a href="https://widgets.sports-reference.com/">Widgets</a></li>
# <li><a href="https://www.sports-reference.com/feedback/">Questions or Comments?</a></li>
# <li class="user logged_in">Welcome<span class="username"></span> · <a href="/my/">Your Account</a></li>
# <li class="user logged_in"><a class="logout" href="/my/?do=logout">Logout</a></li>
# <li class="user not_logged_in"><a class="login" href="/my/">Login</a></li>
# <li class="user not_logged_in"><a href="/my/">Create Account</a></li>
# <li><a href="/my/?do=ad_free_browsing">Surf AD-FREE</a></li>
# </ul>
# <a href="/"><img alt="Basketball-Reference.com Logo &amp; Link to home page" onerror="this.src='https://d2p3bygnnzw9w3.cloudfront.net/req/201711221/logos/bbr-logo.png'; this.onerror = null;" src="https://d2p3bygnnzw9w3.cloudfront.net/req/201711221/logos/bbr-logo.svg"/></a>
# <div id="nav_trigger" role="button"><a href="#site_menu_link">MENU</a></div>
# <div aria-label="Basketball-Reference.com sections" id="nav" role="navigation">
# <ul class="hoversmooth nohover" id="main_nav"><li id="header_players"><a href="/players/">Players</a></li>
# <li id="header_teams"><a href="/teams/">Teams</a></li>
# <li id="header_leagues"><a href="/leagues/">Seasons</a></li>
# <li id="header_leaders"><a href="/leaders/">Leaders</a></li>
# <li id="header_scores"><a href="/boxscores/">Scores</a></li>
# <li class="" id="header_playoffs"><a href="/playoffs/">Playoffs</a></li>
# <li class="" id="header_draft"><a href="/draft/">Draft</a></li>
# <li class="" id="header_playindex"><a href="/play-index/">Play Index</a></li>
# <li><a class="opener" data-scroll="" href="#site_menu_link">Full Site Menu Below</a></li>
# </ul>
# <div class="breadcrumbs">You are here: <div class="crumbs" itemscope="" itemtype="https://schema.org/BreadcrumbList"><span><a href="/">BBR Home</a></span></div></div>
# <ul class="usertools bullets-inline"><li class="user logged_in">Welcome<span class="username"></span> · <a href="/my/">Your Account</a></li>
# <li class="user logged_in"><a class="logout" href="/my/?do=logout">Logout</a></li>
# <li class="user not_logged_in"><a class="login" href="/my/">Login</a></li>
# <li class="user not_logged_in"><a href="/my/">Create Account</a></li>
# <li><a href="/my/?do=ad_free_browsing">Surf AD-FREE</a></li>
# </ul><!-- ul.user -->
# </div><!-- div#nav -->
# <script>
# function sr_menus_setupMainNav_button_inline () {
#     if (sr_detect_operaMini || !("classList" in document.createElement("_"))) {
# 	return false;
#     }
#     var nav_trigger = document.getElementById('nav_trigger');
#     if(!nav_trigger || !Modernizr.is_modern || nav_trigger.triggered) {
# 	return false;
#     }
#     nav_trigger.triggered = true;
#     var nav = document.getElementById('nav');
#     var nav_trigger_a = nav_trigger.querySelector('a');
#     if (nav_trigger_a) {
# 	nav_trigger_a.setAttribute('href','javascript:void(0)');
# 	nav_trigger.onclick = function (event) {
# 	    nav.classList.toggle('open');
# 	    var is_open = nav.classList.contains('open');
# 	    if (is_open) {
# 		nav_trigger.classList.add('open');
# 	    }
# 	    else {
# 		nav_trigger.classList.remove('open');
# 	    }
# 	    event.preventDefault();
# 	    try { sr_record_analytics_event('MainNavButtonClick_inline',sr_record_directory(),sr_record_page());}
# 	    catch(err) {}
# 	};
#     }
#     return true;
# }
# sr_menus_setupMainNav_button_inline();
# </script><div aria-label="Site Search for players, teams and sections" class="search" role="search">
# <form action="/search/search.fcgi" itemprop="potentialAction" itemscope="" itemtype="https://schema.org/SearchAction" name="f_big">
# <meta content="https://www.basketball-reference.com/search/search.fcgi?search={search}" itemprop="target"/>
# <div class="ac-outline">
# <div class="ac-wrapper"><input autocapitalize="off" autocomplete="off" autocorrect="off" class="ac-hint" dir="auto" name="hint" placeholder="" spellcheck="false" tabindex="-1" type="search"/><input aria-label="Enter a player, team or section name" autocapitalize="off" autocomplete="off" autocorrect="off" class="ac-input completely" dir="auto" itemprop="query-input" name="search" placeholder="Enter Person, Team, Section, etc" spellcheck="false" tabindex="1" type="search">
# <div class="ac-dropdown"></div>
# </input></div>
# </div>
# <input tabindex="2" type="submit" value="Search"/>
# <input data-search-id="" name="pid" type="hidden" value=""/>
# <input data-search-idx="" name="idx" type="hidden" value=""/>
# </form>
# </div><!-- div.search -->
# </div><!-- div#header -->
# <script>Modernizr.adfree = true;</script>
# <div class="front" id="content" role="main">
# <h1 id="sr_suppress_ads">Basketball Stats and History <span>Statistics, scores, and history for the NBA, ABA, WNBA, and top European competition.</span></h1>
# <div class="flexindex forcelinear">
# <div class="" id="players">
# <h2><a href="/players/">Every Player</a></h2>
# <div class="images">
# <a href="/players/f/fryech01.html"><img alt="Channing Frye" class="poptip" data-tip="Channing Frye" src="https://d2cwpp38twqe55.cloudfront.net/req/201711161/images/players/fryech01.jpg"/></a>
# <a href="/players/s/stoneju01.html"><img alt="Julyan Stone" class="poptip" data-tip="Julyan Stone" src="https://d2cwpp38twqe55.cloudfront.net/req/201711161/images/players/stoneju01.jpg"/></a>
# <a href="/players/e/edwarsh01.html"><img alt="Shane Edwards" class="poptip" data-tip="Shane Edwards" src="https://d2cwpp38twqe55.cloudfront.net/req/201711161/images/players/edwarsh01.jpg"/></a>
# <a href="/players/p/patteru01.html"><img alt="Ruben Patterson" class="poptip" data-tip="Ruben Patterson" src="https://d2cwpp38twqe55.cloudfront.net/req/201711161/images/players/patteru01.jpg"/></a>
# <a href="/players/j/jonesja02.html"><img alt="James Jones" class="poptip" data-tip="James Jones" src="https://d2cwpp38twqe55.cloudfront.net/req/201711161/images/players/jonesja02.jpg"/></a>
# <a href="/players/o/okafoja01.html"><img alt="Jahlil Okafor" class="poptip" data-tip="Jahlil Okafor" src="https://d2cwpp38twqe55.cloudfront.net/req/201711161/images/players/okafoja01.jpg"/></a>
# <a href="/players/b/bookede01.html"><img alt="Devin Booker" class="poptip" data-tip="Devin Booker" src="https://d2cwpp38twqe55.cloudfront.net/req/201711161/images/players/bookede01.jpg"/></a>
# <a href="/players/d/datomlu01.html"><img alt="Gigi Datome" class="poptip" data-tip="Gigi Datome" src="https://d2cwpp38twqe55.cloudfront.net/req/201711161/images/players/datomlu01.jpg"/></a>
# <a href="/players/g/greendr01.html"><img alt="Draymond Green" class="poptip" data-tip="Draymond Green" src="https://d2cwpp38twqe55.cloudfront.net/req/201711161/images/players/greendr01.jpg"/></a>
# <a href="/players/b/bargnan01.html"><img alt="Andrea Bargnani" class="poptip" data-tip="Andrea Bargnani" src="https://d2cwpp38twqe55.cloudfront.net/req/201711161/images/players/bargnan01.jpg"/></a>
# <a href="/players/r/roseja01.html"><img alt="Jalen Rose" class="poptip" data-tip="Jalen Rose" src="https://d2cwpp38twqe55.cloudfront.net/req/201711161/images/players/roseja01.jpg"/></a>
# <a href="/players/t/telfase01.html"><img alt="Sebastian Telfair" class="poptip" data-tip="Sebastian Telfair" src="https://d2cwpp38twqe55.cloudfront.net/req/201711161/images/players/telfase01.jpg"/></a>
# </div>
# <form action="/route.cgi" class="srbasic sr_goto no-deserialize concat js-select" id="player_roster" method="get">
# <div class="fieldset"><h4>View any Active Player:</h4>
# <div class="formfield">
# <select class="sr_pages_nav no_chosen sr_load_json" data-fill="#player_roster .player_list" data-json-key="player_json" id="selector_0" name="team_val">
# <option disabled="disabled" selected="selected" value="">Choose a Team</option>
# <option value="ATL">Atlanta Hawks</option>
# <option value="BOS">Boston Celtics</option>
# <option value="BRK">Brooklyn Nets</option>
# <option value="CHI">Chicago Bulls</option>
# <option value="CHO">Charlotte Hornets</option>
# <option value="CLE">Cleveland Cavaliers</option>
# <option value="DAL">Dallas Mavericks</option>
# <option value="DEN">Denver Nuggets</option>
# <option value="DET">Detroit Pistons</option>
# <option value="GSW">Golden State Warriors</option>
# <option value="HOU">Houston Rockets</option>
# <option value="IND">Indiana Pacers</option>
# <option value="LAC">Los Angeles Clippers</option>
# <option value="LAL">Los Angeles Lakers</option>
# <option value="MEM">Memphis Grizzlies</option>
# <option value="MIA">Miami Heat</option>
# <option value="MIL">Milwaukee Bucks</option>
# <option value="MIN">Minnesota Timberwolves</option>
# <option value="NOP">New Orleans Pelicans</option>
# <option value="NYK">New York Knicks</option>
# <option value="OKC">Oklahoma City Thunder</option>
# <option value="ORL">Orlando Magic</option>
# <option value="PHI">Philadelphia 76ers</option>
# <option value="PHO">Phoenix Suns</option>
# <option value="POR">Portland Trail Blazers</option>
# <option value="SAC">Sacramento Kings</option>
# <option value="SAS">San Antonio Spurs</option>
# <option value="TOR">Toronto Raptors</option>
# <option value="UTA">Utah Jazz</option>
# <option value="WAS">Washington Wizards</option>
# </select>
# </div>
# <div class="formfield">
# <select class="sr_pages_nav force_chosen player_list" id="selector_0" name="1">
# <option disabled="disabled" selected="selected" value="">Then a player</option>
# <option value="">Really select a team</option>
# </select>
# </div>
# <div class="formfield"><input id="go_button" name="go_button" type="submit" value="Go!"/></div>
# </div>
# </form>
# <form action="/route.cgi" class="srbasic sr_goto no-deserialize single" method="get">
# <div class="fieldset"><h4>Select a Hall of Famer:</h4>
# <div class="formfield">
# <select class="sr_pages_nav" id="selector_1" name="1">
# <option disabled="disabled" selected="selected" value="">Select a player</option>
# <option value="/players/a/abdulka01.html"> Kareem Abdul-Jabbar</option>
# <option value="/players/a/architi01.html"> Tiny Archibald</option>
# <option value="/players/a/arizipa01.html"> Paul Arizin</option>
# <option value="/players/b/barklch01.html"> Charles Barkley</option>
# <option value="/players/b/barksdo01.html"> Don Barksdale</option>
# <option value="/players/b/barryri01.html"> Rick Barry</option>
# <option value="/players/b/bayloel01.html"> Elgin Baylor</option>
# <option value="/players/b/beatyze01.html"> Zelmo Beaty</option>
# <option value="/players/b/bellawa01.html"> Walt Bellamy</option>
# <option value="/players/b/bingda01.html"> Dave Bing</option>
# <option value="/players/b/birdla01.html"> Larry Bird</option>
# <option value="/players/b/bradlbi01.html"> Bill Bradley</option>
# <option value="/players/b/brownla01.html"> Larry Brown</option>
# <option value="/players/b/brownro01.html"> Roger Brown</option>
# <option value="/players/c/cervial01.html"> Al Cervi</option>
# <option value="/players/c/chambwi01.html"> Wilt Chamberlain</option>
# <option value="/players/c/cliftna01.html"> Nat Clifton</option>
# <option value="/players/c/cousybo01.html"> Bob Cousy</option>
# <option value="/players/c/cowenda01.html"> Dave Cowens</option>
# <option value="/players/c/cunnibi01.html"> Billy Cunningham</option>
# <option value="/players/d/dampilo01.html"> Louie Dampier</option>
# <option value="/players/d/danieme01.html"> Mel Daniels</option>
# <option value="/players/d/dantlad01.html"> Adrian Dantley</option>
# <option value="/players/d/daviebo01.html"> Bob Davies</option>
# <option value="/players/d/debusda01.html"> Dave DeBusschere</option>
# <option value="/players/d/drexlcl01.html"> Clyde Drexler</option>
# <option value="/players/d/dumarjo01.html"> Joe Dumars</option>
# <option value="/players/e/embrywa01.html"> Wayne Embry</option>
# <option value="/players/e/englial01.html"> Alex English</option>
# <option value="/players/e/ervinju01.html"> Julius Erving</option>
# <option value="/players/e/ewingpa01.html"> Patrick Ewing</option>
# <option value="/players/f/fraziwa01.html"> Walt Frazier</option>
# <option value="/players/f/fulksjo01.html"> Joe Fulks</option>
# <option value="/players/g/gallaha01.html"> Harry Gallatin</option>
# <option value="/players/g/gervige01.html"> George Gervin</option>
# <option value="/players/g/gilmoar01.html"> Artis Gilmore</option>
# <option value="/players/g/golato01.html"> Tom Gola</option>
# <option value="/players/g/goodrga01.html"> Gail Goodrich</option>
# <option value="/players/g/greerha01.html"> Hal Greer</option>
# <option value="/players/g/gueriri01.html"> Richie Guerin</option>
# <option value="/players/h/hagancl01.html"> Cliff Hagan</option>
# <option value="/players/h/hannual01.html"> Alex Hannum</option>
# <option value="/players/h/havlijo01.html"> John Havlicek</option>
# <option value="/players/h/hawkico01.html"> Connie Hawkins</option>
# <option value="/players/h/hayesel01.html"> Elvin Hayes</option>
# <option value="/players/h/haywosp01.html"> Spencer Haywood</option>
# <option value="/players/h/heinsto01.html"> Tom Heinsohn</option>
# <option value="/players/h/holzmre01.html"> Red Holzman</option>
# <option value="/players/h/houbrbo01.html"> Bob Houbregs</option>
# <option value="/players/h/howelba01.html"> Bailey Howell</option>
# <option value="/players/i/isselda01.html"> Dan Issel</option>
# <option value="/players/i/iversal01.html"> Allen Iverson</option>
# <option value="/players/j/jacksph01.html"> Phil Jackson</option>
# <option value="/players/j/jeannbu01.html"> Buddy Jeannette</option>
# <option value="/players/j/johnsde01.html"> Dennis Johnson</option>
# <option value="/players/j/johnsgu01.html"> Gus Johnson</option>
# <option value="/players/j/johnsma02.html"> Magic Johnson</option>
# <option value="/players/j/johnsne01.html"> Neil Johnston</option>
# <option value="/players/j/joneskc01.html"> K.C. Jones</option>
# <option value="/players/j/jonessa01.html"> Sam Jones</option>
# <option value="/players/j/jordami01.html"> Michael Jordan</option>
# <option value="/players/k/kingbe01.html"> Bernard King</option>
# <option value="/players/l/laniebo01.html"> Bob Lanier</option>
# <option value="/players/l/leonasl01.html"> Slick Leonard</option>
# <option value="/players/l/lloydea01.html"> Earl Lloyd</option>
# <option value="/players/l/lovelcl01.html"> Clyde Lovellette</option>
# <option value="/players/l/lucasje01.html"> Jerry Lucas</option>
# <option value="/players/m/macaued01.html"> Ed Macauley</option>
# <option value="/players/m/malonka01.html"> Karl Malone</option>
# <option value="/players/m/malonmo01.html"> Moses Malone</option>
# <option value="/players/m/maravpe01.html"> Pete Maravich</option>
# <option value="/players/m/marcisa01.html"> Sarunas Marciulionis</option>
# <option value="/players/m/martisl01.html"> Slater Martin</option>
# <option value="/players/m/mcadobo01.html"> Bob McAdoo</option>
# <option value="/players/m/mcginge01.html"> George McGinnis</option>
# <option value="/players/m/mcgratr01.html"> Tracy McGrady</option>
# <option value="/players/m/mcguial01.html"> Alfred McGuire</option>
# <option value="/players/m/mcguidi01.html"> Dick McGuire</option>
# <option value="/players/m/mchalke01.html"> Kevin McHale</option>
# <option value="/players/m/mikange01.html"> George Mikan</option>
# <option value="/players/m/mikkeve01.html"> Vern Mikkelsen</option>
# <option value="/players/m/millere01.html"> Reggie Miller</option>
# <option value="/players/m/mingya01.html"> Yao Ming</option>
# <option value="/players/m/monroea01.html"> Earl Monroe</option>
# <option value="/players/m/mournal01.html"> Alonzo Mourning</option>
# <option value="/players/m/mullich01.html"> Chris Mullin</option>
# <option value="/players/m/murphca01.html"> Calvin Murphy</option>
# <option value="/players/m/mutomdi01.html"> Dikembe Mutombo</option>
# <option value="/players/n/nelsodo01.html"> Don Nelson</option>
# <option value="/players/o/onealsh01.html"> Shaquille O'Neal</option>
# <option value="/players/o/olajuha01.html"> Hakeem Olajuwon</option>
# <option value="/players/p/parisro01.html"> Robert Parish</option>
# <option value="/players/p/paytoga01.html"> Gary Payton</option>
# <option value="/players/p/petrodr01.html"> Drazen Petrovic</option>
# <option value="/players/p/pettibo01.html"> Bob Pettit</option>
# <option value="/players/p/phillan01.html"> Andy Phillip</option>
# <option value="/players/p/pippesc01.html"> Scottie Pippen</option>
# <option value="/players/p/pollaji01.html"> Jim Pollard</option>
# <option value="/players/r/ramsefr01.html"> Frank Ramsey</option>
# <option value="/players/r/reedwi01.html"> Willis Reed</option>
# <option value="/players/r/richmmi01.html"> Mitch Richmond</option>
# <option value="/players/r/rileypa01.html"> Pat Riley</option>
# <option value="/players/r/risenar01.html"> Arnie Risen</option>
# <option value="/players/r/roberos01.html"> Oscar Robertson</option>
# <option value="/players/r/robinda01.html"> David Robinson</option>
# <option value="/players/r/rodgegu01.html"> Guy Rodgers</option>
# <option value="/players/r/rodmade01.html"> Dennis Rodman</option>
# <option value="/players/r/russebi01.html"> Bill Russell</option>
# <option value="/players/s/sabonar01.html"> Arvydas Sabonis</option>
# <option value="/players/s/sampsra01.html"> Ralph Sampson</option>
# <option value="/players/s/sandeto01.html"> Tom Sanders</option>
# <option value="/players/s/schaydo01.html"> Dolph Schayes</option>
# <option value="/players/s/sharmbi01.html"> Bill Sharman</option>
# <option value="/players/s/sloanje01.html"> Jerry Sloan</option>
# <option value="/players/s/stockjo01.html"> John Stockton</option>
# <option value="/players/s/stokema01.html"> Maurice Stokes</option>
# <option value="/players/t/thomais01.html"> Isiah Thomas</option>
# <option value="/players/t/thompda01.html"> David Thompson</option>
# <option value="/players/t/thompjo01.html"> John Thompson</option>
# <option value="/players/t/thurmna01.html"> Nate Thurmond</option>
# <option value="/players/t/twymaja01.html"> Jack Twyman</option>
# <option value="/players/u/unselwe01.html"> Wes Unseld</option>
# <option value="/players/w/walkech01.html"> Chet Walker</option>
# <option value="/players/w/waltobi01.html"> Bill Walton</option>
# <option value="/players/w/wanzebo01.html"> Bobby Wanzer</option>
# <option value="/players/w/westje01.html"> Jerry West</option>
# <option value="/players/w/whitejo01.html"> Jo Jo White</option>
# <option value="/players/w/wilkele01.html"> Lenny Wilkens</option>
# <option value="/players/w/wilkeja01.html"> Jamaal Wilkes</option>
# <option value="/players/w/wilkido01.html"> Dominique Wilkins</option>
# <option value="/players/w/worthja01.html"> James Worthy</option>
# <option value="/players/y/yardlge01.html"> George Yardley</option>
# </select>
# </div>
# <div class="formfield"><input id="go_button" name="go_button" type="submit" value="Go!"/></div>
# </div>
# </form>
# <div>
# <h3><a href="/leagues/NBA_2018_debut.html">Recent Debuts</a></h3>
# <a href="/players/c/craigto01.html">Torrey Craig</a> (DEN),
#     <a href="/players/l/lydonty01.html">Tyler Lydon</a> (DEN),
#     <a href="/players/w/wilsoja02.html">Jamil Wilson</a> (LAC),
#     <a href="/players/p/pulleja01.html">Jacob Pullen</a> (PHI),
#     <a href="/players/h/hollajo02.html">John Holland</a> (CLE) and
#     <a href="/players/c/clevean01.html">Antonius Cleveland</a> (DAL)
# </div>
# <div>
# <h3>In Memoriam</h3>
# <a href="/players/j/jonesst01.html">Steve Jones</a>,
#     <a href="/players/r/reedju01.html">Justin Reed</a>,
#     <a href="/players/h/hawkico01.html">Connie Hawkins</a>,
#     <a href="/coaches/hamblfr99c.html">Frank Hamblen</a>,
#     <a href="/players/m/mcdanji01.html">Jim McDaniels</a> and
#     <a href="/players/h/hawkito01.html">Tom Hawkins</a>
# </div>
# <div>
# <h3><a href="/friv/birthdays.fcgi?month=11&amp;day=29">Happy Birthday</a></h3>
# <a href="/players/s/smithch02.html">Charles Smith</a>,
#     <a href="/players/s/sichtje01.html">Jerry Sichting</a>,
#     <a href="/players/s/stivral01.html">Alex Stivrins</a>,
#     <a href="/players/b/beshode01.html">Del Beshore</a>,
#     <a href="/players/b/brownde01.html">Dee Brown</a> and
#     <a href="/players/m/mashbja01.html">Jamal Mashburn</a>
# </div>
# <p class="note">Player pages include basic statistics and links to player's game logs, splits, advanced stats, and more.</p>
# <script class="allowed">
# var sr_goto_json = (typeof sr_goto_json === 'undefined') ? {} : sr_goto_json;
# sr_goto_json["player_json"] = {
# "ATL": [
#  { "": "Pick a Player" }
# , { "/players/s/schrode01.html" : "Dennis Schroder" }
# , { "/players/b/belinma01.html" : "Marco Belinelli" }
# , { "/players/b/bazemke01.html" : "Kent Bazemore" }
# , { "/players/d/delanma01.html" : "Malcolm Delaney" }
# , { "/players/p/princta02.html" : "Taurean Waller-Prince" }
# , { "/players/b/bembrde01.html" : "DeAndre' Bembry" }
# , { "/players/b/brussni01.html" : "Nicolas Brussino" }
# , { "/players/p/plumlmi01.html" : "Miles Plumlee" }
# , { "/players/c/collijo01.html" : "John Collins" }
# , { "/players/d/dorsety01.html" : "Tyler Dorsey" }
# , { "/players/d/dedmode01.html" : "Dewayne Dedmon" }
# , { "/players/i/ilyaser01.html" : "Ersan Ilyasova" }
# , { "/players/m/muscami01.html" : "Mike Muscala" }
# , { "/players/b/babbilu01.html" : "Luke Babbitt" }
# , { "/players/t/taylois01.html" : "Isaiah Taylor" }
# , { "/players/c/cavanty01.html" : "Tyler Cavanaugh" }
# ], "BOS": [
#  { "": "Pick a Player" }
# , { "/players/i/irvinky01.html" : "Kyrie Irving" }
# , { "/players/m/morrima03.html" : "Marcus Morris" }
# , { "/players/s/smartma01.html" : "Marcus Smart" }
# , { "/players/r/roziete01.html" : "Terry Rozier" }
# , { "/players/h/horfoal01.html" : "Al Horford" }
# , { "/players/b/brownja02.html" : "Jaylen Brown" }
# , { "/players/t/tatumja01.html" : "Jayson Tatum" }
# , { "/players/h/haywago01.html" : "Gordon Hayward" }
# , { "/players/n/naderab01.html" : "Abdel Nader" }
# , { "/players/o/ojelese01.html" : "Semi Ojeleye" }
# , { "/players/b/baynear01.html" : "Aron Baynes" }
# , { "/players/y/yabusgu01.html" : "Guerschon Yabusele" }
# , { "/players/t/theisda01.html" : "Daniel Theis" }
# , { "/players/l/larkish01.html" : "Shane Larkin" }
# , { "/players/b/birdja01.html" : "Jabari Bird" }
# , { "/players/a/allenka01.html" : "Kadeem Allen" }
# ], "BRK": [
#  { "": "Pick a Player" }
# , { "/players/r/russeda01.html" : "D'Angelo Russell" }
# , { "/players/h/holliro01.html" : "Rondae Hollis-Jefferson" }
# , { "/players/c/carrode01.html" : "DeMarre Carroll" }
# , { "/players/k/kilpase01.html" : "Sean Kilpatrick" }
# , { "/players/l/linje01.html" : "Jeremy Lin" }
# , { "/players/m/mozgoti01.html" : "Timofey Mozgov" }
# , { "/players/b/booketr01.html" : "Trevor Booker" }
# , { "/players/c/crabbal01.html" : "Allen Crabbe" }
# , { "/players/w/whiteis01.html" : "Isaiah Whitehead" }
# , { "/players/l/leverca01.html" : "Caris LeVert" }
# , { "/players/h/harrijo01.html" : "Joe Harris" }
# , { "/players/d/dinwisp01.html" : "Spencer Dinwiddie" }
# , { "/players/a/acyqu01.html" : "Quincy Acy" }
# , { "/players/a/allenja01.html" : "Jarrett Allen" }
# , { "/players/z/zellety01.html" : "Tyler Zeller" }
# , { "/players/w/wileyja01.html" : "Jacob Wiley" }
# , { "/players/o/ouattya01.html" : "Yakuba Ouattara" }
# ], "CHI": [
#  { "": "Pick a Player" }
# , { "/players/p/pondequ01.html" : "Quincy Pondexter" }
# , { "/players/l/lavinza01.html" : "Zach LaVine" }
# , { "/players/p/payneca01.html" : "Cameron Payne" }
# , { "/players/g/grantje02.html" : "Jerian Grant" }
# , { "/players/p/portibo01.html" : "Bobby Portis" }
# , { "/players/l/lopezro01.html" : "Robin Lopez" }
# , { "/players/v/valende01.html" : "Denzel Valentine" }
# , { "/players/z/zipsepa01.html" : "Paul Zipser" }
# , { "/players/d/dunnkr01.html" : "Kris Dunn" }
# , { "/players/f/feldeka01.html" : "Kay Felder" }
# , { "/players/n/nwabada01.html" : "David Nwaba" }
# , { "/players/m/markkla01.html" : "Lauri Markkanen" }
# , { "/players/f/feliccr01.html" : "Cristiano Felicio" }
# , { "/players/h/holidju01.html" : "Justin Holiday" }
# , { "/players/m/mirotni01.html" : "Nikola Mirotic" }
# , { "/players/a/arcidry01.html" : "Ryan Arcidiacono" }
# , { "/players/b/blakean01.html" : "Antonio Blakeney" }
# ], "CHO": [
#  { "": "Pick a Player" }
# , { "/players/k/kiddgmi01.html" : "Michael Kidd-Gilchrist" }
# , { "/players/w/walkeke02.html" : "Kemba Walker" }
# , { "/players/z/zelleco01.html" : "Cody Zeller" }
# , { "/players/l/lambje01.html" : "Jeremy Lamb" }
# , { "/players/k/kaminfr01.html" : "Frank Kaminsky" }
# , { "/players/b/batumni01.html" : "Nicolas Batum" }
# , { "/players/w/willima02.html" : "Marvin Williams" }
# , { "/players/h/howardw01.html" : "Dwight Howard" }
# , { "/players/g/grahatr01.html" : "Treveon Graham" }
# , { "/players/o/obryajo01.html" : "Johnny O'Bryant" }
# , { "/players/m/monkma01.html" : "Malik Monk" }
# , { "/players/c/cartemi01.html" : "Michael Carter-Williams" }
# , { "/players/b/bacondw01.html" : "Dwayne Bacon" }
# , { "/players/s/stoneju01.html" : "Julyan Stone" }
# , { "/players/p/paigema01.html" : "Marcus Paige" }
# , { "/players/m/mathima01.html" : "Mangok Mathiang" }
# ], "CLE": [
#  { "": "Pick a Player" }
# , { "/players/f/fryech01.html" : "Channing Frye" }
# , { "/players/t/thomais02.html" : "Isaiah Thomas" }
# , { "/players/c/crowdja01.html" : "Jae Crowder" }
# , { "/players/l/loveke01.html" : "Kevin Love" }
# , { "/players/s/shumpim01.html" : "Iman Shumpert" }
# , { "/players/t/thomptr01.html" : "Tristan Thompson" }
# , { "/players/j/jamesle01.html" : "LeBron James" }
# , { "/players/s/smithjr01.html" : "J.R. Smith" }
# , { "/players/z/zizican01.html" : "Ante Zizic" }
# , { "/players/c/caldejo01.html" : "Jose Calderon" }
# , { "/players/g/greenje02.html" : "Jeff Green" }
# , { "/players/k/korveky01.html" : "Kyle Korver" }
# , { "/players/o/osmande01.html" : "Cedi Osman" }
# , { "/players/r/rosede01.html" : "Derrick Rose" }
# , { "/players/w/wadedw01.html" : "Dwyane Wade" }
# , { "/players/p/perralo01.html" : "London Perrantes" }
# , { "/players/h/hollajo02.html" : "John Holland" }
# ], "DAL": [
#  { "": "Pick a Player" }
# , { "/players/n/noelne01.html" : "Nerlens Noel" }
# , { "/players/m/mcrobjo01.html" : "Josh McRoberts" }
# , { "/players/h/harride01.html" : "Devin Harris" }
# , { "/players/m/matthwe02.html" : "Wesley Matthews" }
# , { "/players/b/bareajo01.html" : "J.J. Barea" }
# , { "/players/m/mejrisa01.html" : "Salah Mejri" }
# , { "/players/b/barneha02.html" : "Harrison Barnes" }
# , { "/players/p/poweldw01.html" : "Dwight Powell" }
# , { "/players/f/finnedo01.html" : "Dorian Finney-Smith" }
# , { "/players/c/curryse01.html" : "Seth Curry" }
# , { "/players/f/ferreyo01.html" : "Yogi Ferrell" }
# , { "/players/s/smithde03.html" : "Dennis Smith" }
# , { "/players/n/nowitdi01.html" : "Dirk Nowitzki" }
# , { "/players/k/klebima01.html" : "Maxi Kleber" }
# , { "/players/w/witheje01.html" : "Jeff Withey" }
# , { "/players/m/motlejo01.html" : "Johnathan Motley" }
# , { "/players/c/clevean01.html" : "Antonius Cleveland" }
# ], "DEN": [
#  { "": "Pick a Player" }
# , { "/players/c/chandwi01.html" : "Wilson Chandler" }
# , { "/players/f/farieke01.html" : "Kenneth Faried" }
# , { "/players/h/harriga01.html" : "Gary Harris" }
# , { "/players/m/mudiaem01.html" : "Emmanuel Mudiay" }
# , { "/players/l/lylestr01.html" : "Trey Lyles" }
# , { "/players/j/jokicni01.html" : "Nikola Jokic" }
# , { "/players/b/bartowi01.html" : "Will Barton" }
# , { "/players/a/arthuda01.html" : "Darrell Arthur" }
# , { "/players/b/beaslma01.html" : "Malik Beasley" }
# , { "/players/m/murraja01.html" : "Jamal Murray" }
# , { "/players/h/hernaju01.html" : "Juan Hernangomez" }
# , { "/players/l/lydonty01.html" : "Tyler Lydon" }
# , { "/players/m/millspa01.html" : "Paul Millsap" }
# , { "/players/p/plumlma01.html" : "Mason Plumlee" }
# , { "/players/j/jefferi01.html" : "Richard Jefferson" }
# , { "/players/m/morrimo01.html" : "Monte Morris" }
# , { "/players/c/craigto01.html" : "Torrey Craig" }
# ], "DET": [
#  { "": "Pick a Player" }
# , { "/players/b/bradlav01.html" : "Avery Bradley" }
# , { "/players/j/johnsst04.html" : "Stanley Johnson" }
# , { "/players/h/harrito02.html" : "Tobias Harris" }
# , { "/players/j/jacksre01.html" : "Reggie Jackson" }
# , { "/players/l/leuerjo01.html" : "Jon Leuer" }
# , { "/players/s/smithis01.html" : "Ish Smith" }
# , { "/players/d/drumman01.html" : "Andre Drummond" }
# , { "/players/m/marjabo01.html" : "Boban Marjanovic" }
# , { "/players/e/ellenhe01.html" : "Henry Ellenson" }
# , { "/players/k/kennalu01.html" : "Luke Kennard" }
# , { "/players/g/gallola01.html" : "Langston Galloway" }
# , { "/players/m/moreler01.html" : "Eric Moreland" }
# , { "/players/b/bullore01.html" : "Reggie Bullock" }
# , { "/players/t/tollian01.html" : "Anthony Tolliver" }
# , { "/players/b/buyckdw01.html" : "Dwight Buycks" }
# , { "/players/m/montelu01.html" : "Luis Montero" }
# ], "GSW": [
#  { "": "Pick a Player" }
# , { "/players/c/curryst01.html" : "Stephen Curry" }
# , { "/players/t/thompkl01.html" : "Klay Thompson" }
# , { "/players/l/looneke01.html" : "Kevon Looney" }
# , { "/players/g/greendr01.html" : "Draymond Green" }
# , { "/players/m/mccawpa01.html" : "Patrick McCaw" }
# , { "/players/j/jonesda03.html" : "Damian Jones" }
# , { "/players/b/belljo01.html" : "Jordan Bell" }
# , { "/players/d/duranke01.html" : "Kevin Durant" }
# , { "/players/i/iguodan01.html" : "Andre Iguodala" }
# , { "/players/l/livinsh01.html" : "Shaun Livingston" }
# , { "/players/y/youngni01.html" : "Nick Young" }
# , { "/players/p/pachuza01.html" : "Zaza Pachulia" }
# , { "/players/c/casspom01.html" : "Omri Casspi" }
# , { "/players/w/westda01.html" : "David West" }
# , { "/players/m/mcgeeja01.html" : "JaVale McGee" }
# , { "/players/c/cookqu01.html" : "Quinn Cook" }
# , { "/players/b/bouchch01.html" : "Chris Boucher" }
# ], "HOU": [
#  { "": "Pick a Player" }
# , { "/players/h/hardeja01.html" : "James Harden" }
# , { "/players/a/arizatr01.html" : "Trevor Ariza" }
# , { "/players/p/paulch01.html" : "Chris Paul" }
# , { "/players/c/capelca01.html" : "Clint Capela" }
# , { "/players/a/anderry01.html" : "Ryan Anderson" }
# , { "/players/g/gordoer01.html" : "Eric Gordon" }
# , { "/players/o/onuakch01.html" : "Chinanu Onuaku" }
# , { "/players/h/hilarne01.html" : "Nene Hilario" }
# , { "/players/t/tuckepj01.html" : "P.J. Tucker" }
# , { "/players/b/blackta01.html" : "Tarik Black" }
# , { "/players/m/mbahalu01.html" : "Luc Mbah a Moute" }
# , { "/players/w/willitr02.html" : "Troy Williams" }
# , { "/players/q/qizh01.html" : "Zhou Qi" }
# , { "/players/b/brownbo02.html" : "Bobby Brown" }
# , { "/players/j/jacksde01.html" : "Demetrius Jackson" }
# , { "/players/w/weberbr01.html" : "Briante Weber" }
# ], "IND": [
#  { "": "Pick a Player" }
# , { "/players/o/oladivi01.html" : "Victor Oladipo" }
# , { "/players/t/turnemy01.html" : "Myles Turner" }
# , { "/players/y/youngth01.html" : "Thaddeus Young" }
# , { "/players/j/josepco01.html" : "Cory Joseph" }
# , { "/players/r/robingl02.html" : "Glenn Robinson" }
# , { "/players/y/youngjo01.html" : "Joe Young" }
# , { "/players/j/jeffeal01.html" : "Al Jefferson" }
# , { "/players/s/sabondo01.html" : "Domantas Sabonis" }
# , { "/players/s/stephla01.html" : "Lance Stephenson" }
# , { "/players/l/leaftj01.html" : "T.J. Leaf" }
# , { "/players/b/bogdabo02.html" : "Bojan Bogdanovic" }
# , { "/players/a/anigbik01.html" : "Ike Anigbogu" }
# , { "/players/c/collida01.html" : "Darren Collison" }
# , { "/players/w/wilkida02.html" : "Damien Wilkins" }
# , { "/players/p/poythal01.html" : "Alex Poythress" }
# , { "/players/s/sumneed01.html" : "Edmond Sumner" }
# ], "LAC": [
#  { "": "Pick a Player" }
# , { "/players/d/dekkesa01.html" : "Sam Dekker" }
# , { "/players/b/beverpa01.html" : "Patrick Beverley" }
# , { "/players/j/jordade01.html" : "DeAndre Jordan" }
# , { "/players/w/willilo02.html" : "Lou Williams" }
# , { "/players/h/harremo01.html" : "Montrezl Harrell" }
# , { "/players/r/riverau01.html" : "Austin Rivers" }
# , { "/players/j/johnswe01.html" : "Wesley Johnson" }
# , { "/players/j/johnsbr02.html" : "Brice Johnson" }
# , { "/players/g/gallida01.html" : "Danilo Gallinari" }
# , { "/players/t/teodomi01.html" : "Milos Teodosic" }
# , { "/players/e/evansja01.html" : "Jawun Evans" }
# , { "/players/g/griffbl01.html" : "Blake Griffin" }
# , { "/players/t/thornsi01.html" : "Sindarius Thornwell" }
# , { "/players/r/reedwi02.html" : "Willie Reed" }
# , { "/players/w/willicj01.html" : "C.J. Williams" }
# , { "/players/w/wilsoja02.html" : "Jamil Wilson" }
# ], "LAL": [
#  { "": "Pick a Player" }
# , { "/players/r/randlju01.html" : "Julius Randle" }
# , { "/players/n/nancela02.html" : "Larry Nance" }
# , { "/players/l/lopezbr01.html" : "Brook Lopez" }
# , { "/players/b/breweco01.html" : "Corey Brewer" }
# , { "/players/d/denglu01.html" : "Luol Deng" }
# , { "/players/z/zubaciv01.html" : "Ivica Zubac" }
# , { "/players/c/clarkjo01.html" : "Jordan Clarkson" }
# , { "/players/i/ingrabr01.html" : "Brandon Ingram" }
# , { "/players/b/balllo01.html" : "Lonzo Ball" }
# , { "/players/k/kuzmaky01.html" : "Kyle Kuzma" }
# , { "/players/h/hartjo01.html" : "Josh Hart" }
# , { "/players/c/caldwke01.html" : "Kentavious Caldwell-Pope" }
# , { "/players/e/ennisty01.html" : "Tyler Ennis" }
# , { "/players/b/bryanth01.html" : "Thomas Bryant" }
# , { "/players/b/bogutan01.html" : "Andrew Bogut" }
# , { "/players/b/blueva01.html" : "Vander Blue" }
# ], "MEM": [
#  { "": "Pick a Player" }
# , { "/players/g/gasolma01.html" : "Marc Gasol" }
# , { "/players/m/martija01.html" : "Jarell Martin" }
# , { "/players/w/wrighbr03.html" : "Brandan Wright" }
# , { "/players/p/parsoch01.html" : "Chandler Parsons" }
# ...
# </div>
# <div class="division">
# <strong>Southwest</strong>:
#       <a href="/teams/SAS/2018.html">San Antonio</a>,
#       <a href="/teams/DAL/2018.html">Dallas</a>,
#       <a href="/teams/MEM/2018.html">Memphis</a>,
#       <a href="/teams/HOU/2018.html">Houston</a>,
#       <a href="/teams/NOP/2018.html">New Orleans</a>
# </div>
# </li>
# <li>
# <a href="/leagues/">Seasons</a>
# <div>
# <a href="/leagues/NBA_2018.html">2017-18</a>,
#       <a href="/leagues/NBA_2017.html">2016-17</a>,
#       <a href="/leagues/NBA_2016.html">2015-16</a>,
#       <a href="/leagues/NBA_2015.html">2014-15</a>,
#       <a href="/leagues/NBA_2014.html">2013-14</a>,
#       <a href="/leagues/NBA_2013.html">2012-13</a>
# </div>
# </li>
# <li>
# <a href="/leaders/">Leaders</a>
# <div>
# <a href="/leaders/pts_season.html">Season Points</a>,
#       <a href="/leaders/trb_career.html">Career Rebounds</a>,
#       <a href="/leaders/ast_active.html">Active Assists</a>,
#       <a href="/leaders/stl_yearly.html">Yearly Steals</a>,
#       <a href="/leaders/blk_progress.html">Progressive Blocks</a>
#       ...
#     </div>
# <div>
#       Or, view <a href="/trailers/">"Trailers"</a> for <a href="/trailers/fg_pct_season.html">Season Field Goal Pct</a>, or <a href="/trailers/blk_per_g_career.html">Career Blocks Per Game</a>
# </div>
# </li>
# <li>
# <a href="/boxscores/">NBA Scores</a>
# <div>
# <a href="/boxscores/">Yesterday's Games</a> and <a href="/boxscores/">Scores from any date in BAA/NBA or ABA history</a>
# </div>
# </li>
# <li>
# <a href="/leagues/NBA_2018_games.html">NBA Schedules</a>
# <div>
# <a href="/teams/CHI/2018_games.html">Team Schedules</a> and <a href="/leagues/NBA_2018_games.html">League Schedules</a>
# </div>
# </li>
# <li>
# <a href="/leagues/NBA_2018_standings.html">NBA Standings</a>
# <div>
# <a href="/leagues/NBA_2018_standings.html">Today's Standings</a> and <a href="/friv/standings.fcgi">Standings for any date in history</a>
# </div>
# </li>
# <li>
# <a href="/play-index/">Play Index</a>
# <div><strong>Player Finders</strong>:
#       <a href="/play-index/psl_finder.cgi">Season Finder</a>,
#       <a href="/play-index/pgl_finder.cgi">Game Finder</a>,
#       <a href="/play-index/pstreak.cgi">Streak Finder</a>
# </div>
# <div><strong>Team Finders</strong>:
#       <a href="/play-index/tsl_finder.cgi">Season Finder</a>,
#       <a href="/play-index/tgl_finder.cgi">Game Finder</a>,
#       <a href="/play-index/tstreak.cgi">Team Streak Finder</a>,
#       <a href="/play-index/tscore.cgi">Team Score Finder</a>,
#       <a href="/play-index/rivals.cgi">Team Rivalry Finder</a>
# </div>
# <div><strong>Other Finders</strong>:
#       <a href="/play-index/draft_finder.cgi">Draft Finder</a>,
#       <a href="/play-index/h2h_finder.cgi">Head2Head Finder</a>,
#       <a href="/play-index/pcm_finder.cgi">Player Comparison Finder</a>
# </div>
# </li>
# <li>
# <a href="/coaches/">Coaches</a>
# <div>
# <a href="/coaches/gueriri01c.html">Richie Guerin</a>,
#       <a href="/coaches/tomjaru01c.html">Rudy Tomjanovich</a>,
#       <a href="/coaches/obrieji99c.html">Jim O'Brien</a>,
#       <a href="/coaches/fratemi99c.html">Mike Fratello</a>,
#       <a href="/coaches/gentral99c.html">Alvin Gentry</a>
# </div>
# </li>
# <li>
# <a href="/awards/">Awards</a>
# <div>
# <a href="/awards/mvp.html">NBA MVP</a>,
#       <a href="/awards/all_league.html">All-NBA</a>,
#       <a href="/awards/dpoy.html">Defensive Player of the Year</a>,
#       <a href="/awards/roy.html">Rookie of the Year</a>,
#       <a href="/awards/all_rookie.html">All-Rookie</a>,
#       <a href="/awards/hof.html">Hall of Fame</a>
#       ...
#     </div>
# </li>
# <li>
# <a href="/contracts/">NBA Contracts</a>
# <div>
# <a href="/contracts/">Main Index</a>,
#       <a href="/contracts/ATL.html">Team Payrolls</a>,
#       <a href="/contracts/players.html">Player Contracts</a>,
#       <a href="/contracts/glossary.html">Glossary</a>,
#       ...
#     </div>
# </li>
# <li>
# <a href="/playoffs/">Playoffs</a>
# <div>
# <a href="/playoffs/NBA_2017.html">2017 NBA Playoffs</a>,
#       <a href="/playoffs/NBA_2016.html">2016 NBA Playoffs</a>,
#       <a href="/playoffs/NBA_2015.html">2015 NBA Playoffs</a>,
#       <a href="/playoffs/NBA_2014.html">2014 NBA Playoffs</a>,
#       <a href="/playoffs/">Playoffs Series History</a>
#       ...
#     </div>
# </li>
# <li>
# <a href="/allstar/">All-Star Games</a>
# <div>
# <a href="/allstar/NBA_2017.html">2017 All-Star Game</a>,
#       <a href="/allstar/NBA_2016.html">2016 All-Star Game</a>,
#       <a href="/allstar/NBA_2015.html">2015 All-Star Game</a>,
#       <a href="/allstar/NBA_2014.html">2014 All-Star Game</a>,
#       ...
#     </div>
# </li>
# <li>
# <a href="/draft/">NBA Draft</a>
# <div>
# <a href="/draft/NBA_2017.html">2017 Draft</a>,
#       <a href="/draft/NBA_2016.html">2016 Draft</a>,
#       <a href="/draft/NBA_2015.html">2015 Draft</a>,
#       <a href="/draft/NBA_2014.html">2014 Draft</a>,
#       <a href="/draft/NBA_2013.html">2013 Draft</a>,
#       ...
#     </div>
# </li>
# <li>
# <a href="/friv/">Frivolities</a>
# <div>
# <a href="/friv/birthdays.fcgi">Birthdays</a>,
#       <a href="/friv/colleges.cgi">Colleges</a>,
#       <a href="/friv/high_schools.cgi">High Schools</a>,
#       <a href="/friv/milestones.cgi">Milestone Watch</a>
#       ...
#     </div>
# </li>
# <li>
# <a href="/executives/">Executives</a>
# <div>
# <a href="/executives/buforrc99x.html">R.C. Buford</a>,
#       <a href="/executives/embrywa01x.html">Wayne Embry</a>,
#       <a href="/executives/kastest99x.html">Stan Kasten</a>,
#       <a href="/executives/aingeda01x.html">Danny Ainge</a>,
#       <a href="/executives/nelsodo01x.html">Don Nelson</a>
#       ...
#     </div>
# </li>
# <li>
# <a href="/referees/">Referees</a>
# <div>
# <a href="/referees/fortejo99r.html">Joe Forte</a>,
#       <a href="/referees/brothto99r.html">Tony Brothers</a>,
#       <a href="/referees/crawfda99r.html">Dan Crawford</a>,
#       <a href="/referees/olesiro99r.html">Ron Olesiak</a>,
#       <a href="/referees/jonesda99r.html">David Jones</a>
#       ...
#     </div>
# </li>
# <li>
# <a href="/gleague/">G-League Stats</a>
# <div>
# <a href="/gleague/players/">Players</a>,
#       <a href="/gleague/teams/">Teams</a>,
#       <a href="/gleague/years/">Seasons</a>,
#       <a href="/gleague/leaders/">Leaders</a>,
#       <a href="/gleague/awards/">Awards</a>
#       ...
#     </div>
# </li>
# <li>
# <a href="/euro/">Euro Basketball Stats</a>
# <div>
# <a href="/euro/players/">Players</a>,
#       <a href="/euro/teams/">Teams</a>,
#       <a href="/euro/years/">Seasons</a>,
#       <a href="/euro/leaders/">Leaders</a>,
#       <a href="/euro/awards/">Awards</a>
#       ...
#     </div>
# </li>
# <li>
# <a href="/wnba/">WNBA</a>
# <div>
# <a href="/wnba/players/">Players</a>,
#       <a href="/wnba/teams/">Teams</a>,
#       <a href="/wnba/years/">Seasons</a>,
#       <a href="/wnba/leaders/">Leaders</a>,
#       <a href="/wnba/awards/">Awards</a>
#       ...
#     </div>
# </li>
# <li>
# <a href="/olympics/">Olympics Stats</a>
# <div>
# <a href="/olympics/athletes/">Athletes</a>,
#       <a href="/olympics/teams/">Teams</a>,
#       <a href="/olympics/years/">Years</a>,
#       <a href="/olympics/games/">Games</a>,
#       ...
#     </div>
# </li>
# <li>
# <a href="/nbl/">NBL</a>
# <div>
# <a href="/nbl/players/">Players</a>,
#       <a href="/nbl/teams/">Teams</a>,
#       <a href="/nbl/years/">Seasons</a>,
#       <a href="/nbl/leaders/">Leaders</a>,
#       <a href="/nbl/awards/">Awards</a>
#       ...
#     </div>
# </li>
# <li>
# <a href="/about/">About</a>
# <div>
# <a href="/about/glossary.html">Glossary</a>,
#       <a href="/about/contact.html">Contact and Media Information</a>,
#       ...
#     </div>
# </li>
# </ul>
# </div><!-- div#site_menu -->
# <div class="icon_group noload" id="social">
# <div class="section_heading">
# <span class="section_anchor" data-label="We're Social...for Statheads" data-no-inpage="1" id="_link"></span>
# <h2>We're Social...for Statheads</h2>
# </div>
# <a class="poptip" data-label="Telephone" data-tip="Call us on Telephone" href="tel://800-512-8907"><svg class="icon phone"><use xlink:href="#ic-phone"></use></svg></a>
# <a class="poptip" data-label="Our Blog" data-tip="The Sports Reference Blog" href="//www.sports-reference.com/blog/"><svg class="icon wordpress"><use xlink:href="#ic-wordpress"></use></svg></a>
# <a class="poptip" data-label="RSS Feed" data-tip="Our Blog's RSS Feed" href="https://www.sports-reference.com/blog/feed/"><svg class="icon rss"><use xlink:href="#ic-rss"></use></svg></a>
# <a class="poptip" data-label="Facebook" data-tip="Basketball-Reference.com at Facebook" href="https://www.facebook.com/Basketball.Reference"><svg class="icon facebook"><use xlink:href="#ic-facebook"></use></svg></a>
# <a class="poptip" data-label="Twitter" data-tip="Basketball-Reference.com at Twitter" href="https://twitter.com/bball_ref"><svg class="icon twitter"><use xlink:href="#ic-twitter"></use></svg></a>
# <a class="poptip" data-label="Reddit/r/SR" data-tip="Reddit/r/SportsReference" href="https://reddit.com/r/SportsReference"><svg class="icon reddit"><use xlink:href="#ic-reddit"></use></svg></a>
# <a class="poptip" data-label="YouTube" data-tip="YouTube/SportsReference" href="https://www.youtube.com/user/sportsreference"><svg class="icon youtube"><use xlink:href="#ic-youtube"></use></svg></a>
# <a class="poptip" data-label="LinkedIn" data-tip="Follow SR on LinkedIn" href="https://www.linkedin.com/company/sports-reference-llc"><svg class="icon linkedin"><use xlink:href="#ic-linkedin"></use></svg></a>
# <a class="poptip" data-label="PayPal" data-tip="Send us money via PayPal" href="https://www.paypal.me/sportsref"><svg class="icon paypal"><use xlink:href="#ic-paypal"></use></svg></a>
# <p>Every <a href="https://www.sports-reference.com/blog/sports-reference-social-media/">Sports Reference Social Media Account</a></p>
# <p><strong>Site Last Updated:</strong> Wednesday, November 29,  4:52AM
# </p>
# <a class="button alt" href="https://www.sports-reference.com/feedback/">Question, Comment, Feedback, or Correction?</a>
# </div><!-- div#social -->
# <div id="tips_tricks">
# <div class="section_heading">
# <span class="section_anchor" data-label="FAQs, Tip &amp; Tricks" data-no-inpage="1" id="tips_link"></span>
# <h2>FAQs, Tip &amp; Tricks</h2>
# </div>
# <ul>
# <li><a href="//www.sports-reference.com/blog/category/tips-and-tricks/">Tips and Tricks from our Blog.</a></li>
# <li><a href="/linker/">Do you have a blog? Join our linker program.</a></li>
# <li><a href="//www.sports-reference.com/blog/category/how-to-videos/">Watch our How-To Videos to Become a Stathead</a></li>
# <li><a href="/my/?do=ad_free_browsing">Go ad-free to support Sports Reference and get our fastest browsing experience</a></li>
# <li><a href="//www.baseball-reference.com/play-index/">Subscribe to the Play Index and get access to more data than you can imagine</a></li>
# <!-- no Local/FooterTipsTricks.tt2 -->
# </ul>
# </div><!-- div#tips_tricks -->
# <div id="credits">
# <p>All logos are the trademark &amp; property of their owners and not Sports Reference LLC.  We present them here for purely educational purposes.
#         <a href="https://www.sports-reference.com/blog/2016/06/redesign-team-and-league-logos-courtesy-sportslogos-net/">Our reasoning for presenting offensive logos.</a></p>
# <p>Logos were compiled by the amazing <a href="http://sportslogos.net/">SportsLogos.net.</a></p>
# <div class="notice">Primary Data Provided By
# 	<a href="http://www.gracenote.com/sports/sports-data/" rel="nofollow"><img alt="Gracenote Sports" border="0" src="https://d2p3bygnnzw9w3.cloudfront.net/req/201711221/images/klecko/gracenote.png" width="275"/></a>
# </div>
# <p>Copyright © 2000-2017 <a href="//www.sports-reference.com/">Sports Reference LLC</a>. All rights reserved.</p>
# </div><!-- div#credits -->
# <ul class="bullets-inline" id="site_dirs">
# <li><a href="https://www.sports-reference.com/"><svg height="15px" width="20px"><use xlink:href="#ic-sr-pennant"></use></svg> Sports Reference</a></li>
# <li><a href="https://www.baseball-reference.com/">Baseball</a></li>
# <li><a href="https://www.pro-football-reference.com/">Football</a> <a href="https://www.sports-reference.com/cfb/">(college)</a></li>
# <li class="current"><a href="https://www.basketball-reference.com/">Basketball</a> <a href="https://www.sports-reference.com/cbb/">(college)</a></li>
# <li><a href="https://www.hockey-reference.com/">Hockey</a></li>
# <li><a href="https://fbref.com/">Soccer</a></li>
# <li><a href="https://www.sports-reference.com/blog/">Blog</a></li>
# <li><a href="https://widgets.sports-reference.com/">Widgets</a></li>
# </ul>
# <div id="about"><a href="//www.sports-reference.com/about.html">About</a> • <a href="//www.sports-reference.com/privacy.html">Privacy Statement</a> • <a href="//www.sports-reference.com/termsofuse.html">Conditions &amp; Terms of Service</a> • <a href="//www.sports-reference.com/data_use.html">Use of Data</a></div><!-- div#about -->
# </div><!-- div#footer -->
# <!-- div#wrap -->
# <!-- Google Analytics --><script> String.prototype.sr_isMatch = function(s){ return this.match(s)!==null}; function getCookie(name) { var prefix = name + "="; var begin = document.cookie.indexOf("; " + prefix); if (begin == -1) { begin = document.cookie.indexOf(prefix); if (begin != 0) return null; } else { begin += 2; var end = document.cookie.indexOf(";", begin); if (end == -1) { end = document.cookie.length; } } return unescape(document.cookie.substring(begin + prefix.length, end));} var sr_cookie = getCookie('SR_user') || ''; var sr_is_ad_free = sr_cookie.sr_isMatch('Z6SON8tTdJid'); var sr_is_user = sr_cookie !== null && sr_cookie !== ''; var sr_seen_modal = getCookie('modal_ad') !== null; (function(i,s,o,g,r,a,m){ i['GoogleAnalyticsObject']=r; i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date(); a=s.createElement(o),m=s.getElementsByTagName(o)[0]; a.async=1; a.src=g; m.parentNode.insertBefore(a,m) })(window,document,'script','https://www.google-analytics.com/analytics.js','ga'); ga('create', 'UA-1890630-2', 'auto'); ga('require', 'linkid', 'linkid.js'); ga('require', 'ecommerce', 'ecommerce.js'); ga('send', 'pageview'); ga('create', 'UA-1890630-20', 'auto', {'name': 'combined_tracker', 'allowLinker': true }); ga('combined_tracker.send', 'pageview'); var sr_device = 'unk'; if (Modernizr.phone) { sr_device = 'phone'; } else if (Modernizr.tablet) { sr_device = 'tablet'; } else if (Modernizr.laptop) { sr_device = 'laptop'; } else if (Modernizr.desktop) { sr_device = 'desktop'; } ga('create', 'UA-1890630-9', 'auto', {'name': 'sr_tracker', 'allowLinker': true }); ga('sr_tracker.require', 'displayfeatures'); ga('sr_tracker.set', 'dimension1','bbr'); ga('sr_tracker.set', 'dimension2',sr_is_ad_free); ga('sr_tracker.set', 'dimension3',sr_is_user); ga('sr_tracker.set', 'dimension4',sr_seen_modal); ga('sr_tracker.set', 'dimension5',sr_device); ga('sr_tracker.set', 'dimension6',Modernizr.is_modern?'yes':'no'); ga('sr_tracker.set', 'dimension7',Modernizr.viewport_width); /* note that this requires the Assets/AdBlockTest.tt2 to be included above. */ ga('sr_tracker.set', 'dimension8',(typeof sr_test == 'undefined')?'no-test':( sr_test ? 'non-blocking':'blocking')); ga('sr_tracker.send', 'pageview'); /* cribbed from: http://www.axllent.org/docs/view/track-outbound-links-with-analytics-js/ */ function _gaLt(event) { if (!ga.hasOwnProperty("loaded") || ga.loaded != true) { return; } var el = event.srcElement || event.target; /* if a link has been clicked */ if (el && el.href) { var link = el.href; /* Only if it is an external link */ if (link.indexOf(location.host) == -1 && !link.match(/^javascript\:/i)) { /* Is target set and not _(self|parent|top)? */ var target = (el.target && !el.target.match(/^_(self|parent|top)/i)) ? el.target : false; /* If target opens a new window then just track */ if (el.target && !el.target.match(/^_(self|parent|top)/i)) { ga("send", "event", "Outgoing Links", link, document.location.pathname + document.location.search); } }; } } window.addEventListener ? window.addEventListener("load", function() { document.body.addEventListener("click", _gaLt, !1)}, !1) : window.attachEvent && window.attachEvent("onload", function() { document.body.attachEvent("onclick", _gaLt) }); </script><!-- End Google Analytics -->
# <!-- SR -->

# %%
data = []
for a in page.find_all("tr", class_="full_table"):
    for b in a.find_all("a"):
        if('20' in b["href"]):
            data.append(dict(zip(['team','link'], [b["title"], "http://www.basketball-reference.com" + b["href"]])))
df = pd.DataFrame(data, columns=['team','link'])
df
# Out:
#                       team                                               link
# 0           Boston Celtics  http://www.basketball-reference.com/teams/BOS/...
# 1          Detroit Pistons  http://www.basketball-reference.com/teams/DET/...
# 2      Cleveland Cavaliers  http://www.basketball-reference.com/teams/CLE/...
# 3          Toronto Raptors  http://www.basketball-reference.com/teams/TOR/...
# 4       Philadelphia 76ers  http://www.basketball-reference.com/teams/PHI/...
# 5           Indiana Pacers  http://www.basketball-reference.com/teams/IND/...
# 6       Washington Wizards  http://www.basketball-reference.com/teams/WAS/...
# 7          Milwaukee Bucks  http://www.basketball-reference.com/teams/MIL/...
# 8               Miami Heat  http://www.basketball-reference.com/teams/MIA/...
# 9          New York Knicks  http://www.basketball-reference.com/teams/NYK/...
# 10       Charlotte Hornets  http://www.basketball-reference.com/teams/CHO/...
# 11           Orlando Magic  http://www.basketball-reference.com/teams/ORL/...
# 12           Brooklyn Nets  http://www.basketball-reference.com/teams/BRK/...
# 13           Atlanta Hawks  http://www.basketball-reference.com/teams/ATL/...
# 14           Chicago Bulls  http://www.basketball-reference.com/teams/CHI/...
# 15         Houston Rockets  http://www.basketball-reference.com/teams/HOU/...
# 16   Golden State Warriors  http://www.basketball-reference.com/teams/GSW/...
# 17       San Antonio Spurs  http://www.basketball-reference.com/teams/SAS/...
# 18  Portland Trail Blazers  http://www.basketball-reference.com/teams/POR/...
# 19  Minnesota Timberwolves  http://www.basketball-reference.com/teams/MIN/...
# 20    New Orleans Pelicans  http://www.basketball-reference.com/teams/NOP/...
# 21          Denver Nuggets  http://www.basketball-reference.com/teams/DEN/...
# 22               Utah Jazz  http://www.basketball-reference.com/teams/UTA/...
# 23    Los Angeles Clippers  http://www.basketball-reference.com/teams/LAC/...
# 24   Oklahoma City Thunder  http://www.basketball-reference.com/teams/OKC/...
# 25      Los Angeles Lakers  http://www.basketball-reference.com/teams/LAL/...
# 26       Memphis Grizzlies  http://www.basketball-reference.com/teams/MEM/...
# 27            Phoenix Suns  http://www.basketball-reference.com/teams/PHO/...
# 28        Sacramento Kings  http://www.basketball-reference.com/teams/SAC/...
# 29        Dallas Mavericks  http://www.basketball-reference.com/teams/DAL/...

# %%
all_links = []
for row in df.itertuples():
    team = row[1]
    link = row[2]
    l = link[0:link.rfind('/')+1]
    for i in range(2008,2019):
        all_links.append(dict(zip(["team","links"],[team,l + str(i) + ".html"])))
#print(all_links)
tets = pd.DataFrame(all_links, columns=["team","links"])
tets
# Out:
#                     team                                              links
# 0         Boston Celtics  http://www.basketball-reference.com/teams/BOS/...
# 1         Boston Celtics  http://www.basketball-reference.com/teams/BOS/...
# 2         Boston Celtics  http://www.basketball-reference.com/teams/BOS/...
# 3         Boston Celtics  http://www.basketball-reference.com/teams/BOS/...
# 4         Boston Celtics  http://www.basketball-reference.com/teams/BOS/...
# 5         Boston Celtics  http://www.basketball-reference.com/teams/BOS/...
# 6         Boston Celtics  http://www.basketball-reference.com/teams/BOS/...
# 7         Boston Celtics  http://www.basketball-reference.com/teams/BOS/...
# 8         Boston Celtics  http://www.basketball-reference.com/teams/BOS/...
# 9         Boston Celtics  http://www.basketball-reference.com/teams/BOS/...
# 10        Boston Celtics  http://www.basketball-reference.com/teams/BOS/...
# 11       Detroit Pistons  http://www.basketball-reference.com/teams/DET/...
# 12       Detroit Pistons  http://www.basketball-reference.com/teams/DET/...
# 13       Detroit Pistons  http://www.basketball-reference.com/teams/DET/...
# 14       Detroit Pistons  http://www.basketball-reference.com/teams/DET/...
# 15       Detroit Pistons  http://www.basketball-reference.com/teams/DET/...
# 16       Detroit Pistons  http://www.basketball-reference.com/teams/DET/...
# 17       Detroit Pistons  http://www.basketball-reference.com/teams/DET/...
# 18       Detroit Pistons  http://www.basketball-reference.com/teams/DET/...
# 19       Detroit Pistons  http://www.basketball-reference.com/teams/DET/...
# 20       Detroit Pistons  http://www.basketball-reference.com/teams/DET/...
# 21       Detroit Pistons  http://www.basketball-reference.com/teams/DET/...
# 22   Cleveland Cavaliers  http://www.basketball-reference.com/teams/CLE/...
# 23   Cleveland Cavaliers  http://www.basketball-reference.com/teams/CLE/...
# 24   Cleveland Cavaliers  http://www.basketball-reference.com/teams/CLE/...
# 25   Cleveland Cavaliers  http://www.basketball-reference.com/teams/CLE/...
# 26   Cleveland Cavaliers  http://www.basketball-reference.com/teams/CLE/...
# 27   Cleveland Cavaliers  http://www.basketball-reference.com/teams/CLE/...
# 28   Cleveland Cavaliers  http://www.basketball-reference.com/teams/CLE/...
# 29   Cleveland Cavaliers  http://www.basketball-reference.com/teams/CLE/...
# ..                   ...                                                ...
# 300         Phoenix Suns  http://www.basketball-reference.com/teams/PHO/...
# 301         Phoenix Suns  http://www.basketball-reference.com/teams/PHO/...
# 302         Phoenix Suns  http://www.basketball-reference.com/teams/PHO/...
# 303         Phoenix Suns  http://www.basketball-reference.com/teams/PHO/...
# 304         Phoenix Suns  http://www.basketball-reference.com/teams/PHO/...
# 305         Phoenix Suns  http://www.basketball-reference.com/teams/PHO/...
# 306         Phoenix Suns  http://www.basketball-reference.com/teams/PHO/...
# 307         Phoenix Suns  http://www.basketball-reference.com/teams/PHO/...
# 308     Sacramento Kings  http://www.basketball-reference.com/teams/SAC/...
# 309     Sacramento Kings  http://www.basketball-reference.com/teams/SAC/...
# 310     Sacramento Kings  http://www.basketball-reference.com/teams/SAC/...
# 311     Sacramento Kings  http://www.basketball-reference.com/teams/SAC/...
# 312     Sacramento Kings  http://www.basketball-reference.com/teams/SAC/...
# 313     Sacramento Kings  http://www.basketball-reference.com/teams/SAC/...
# 314     Sacramento Kings  http://www.basketball-reference.com/teams/SAC/...
# 315     Sacramento Kings  http://www.basketball-reference.com/teams/SAC/...
# 316     Sacramento Kings  http://www.basketball-reference.com/teams/SAC/...
# 317     Sacramento Kings  http://www.basketball-reference.com/teams/SAC/...
# 318     Sacramento Kings  http://www.basketball-reference.com/teams/SAC/...
# 319     Dallas Mavericks  http://www.basketball-reference.com/teams/DAL/...
# 320     Dallas Mavericks  http://www.basketball-reference.com/teams/DAL/...
# 321     Dallas Mavericks  http://www.basketball-reference.com/teams/DAL/...
# 322     Dallas Mavericks  http://www.basketball-reference.com/teams/DAL/...
# 323     Dallas Mavericks  http://www.basketball-reference.com/teams/DAL/...
# 324     Dallas Mavericks  http://www.basketball-reference.com/teams/DAL/...
# 325     Dallas Mavericks  http://www.basketball-reference.com/teams/DAL/...
# 326     Dallas Mavericks  http://www.basketball-reference.com/teams/DAL/...
# 327     Dallas Mavericks  http://www.basketball-reference.com/teams/DAL/...
# 328     Dallas Mavericks  http://www.basketball-reference.com/teams/DAL/...
# 329     Dallas Mavericks  http://www.basketball-reference.com/teams/DAL/...
#
# [330 rows x 2 columns]
