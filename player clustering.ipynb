# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans

# %%
season_2014_15 = pd.read_csv('season_players/2014-2015.csv')
season_2014_15 = season_2014_15.drop('Unnamed: 0', axis=1)

season_2015_16 = pd.read_csv('season_players/2015-2016.csv')
season_2015_16 = season_2015_16.drop('Unnamed: 0', axis=1)

season_2016_17 = pd.read_csv('season_players/2016-2017.csv')
season_2016_17 = season_2016_17.drop('Unnamed: 0', axis=1)

season_2017_18 = pd.read_csv('season_players/2017-2018.csv')
season_2017_18 = season_2017_18.drop('Unnamed: 0', axis=1)

# %%
df_final_full = pd.concat([season_2014_15,season_2015_16,season_2016_17,season_2017_18], ignore_index=True)
df_final = df_final_full.drop(['Team','Season','Name'],axis=1).fillna(0)
df_final
# Out:
#       Age   G  GS    MP   FG   FGA    FG%   3P  3PA    3P%  ...      FT%  ORB  \
# 0      28  33  33  33.1  6.2  14.4  0.434  1.4  4.7  0.305  ...    0.840  0.6
# 1      28  22  22  31.8  3.7   9.1  0.405  0.4  1.5  0.250  ...    0.333  1.1
# 2      24  77  77  31.5  5.6  13.1  0.429  1.6  4.6  0.352  ...    0.790  0.6
# 3      26  82  57  27.6  3.9   9.1  0.429  0.4  1.5  0.277  ...    0.752  0.5
# 4      22  58  49  27.0  5.4  12.2  0.439  0.9  3.2  0.283  ...    0.744  2.5
# 5      20  67  38  27.0  2.6   7.1  0.367  1.4  4.1  0.335  ...    0.646  0.9
# 6      25  21   0  26.0  5.6  13.6  0.411  2.3  6.6  0.345  ...    0.861  0.3
# 7      24  57  17  24.2  3.4   8.2  0.418  0.8  3.0  0.282  ...    0.762  1.1
# 8      29  82  43  23.5  4.2   8.3  0.504  0.1  0.4  0.281  ...    0.790  1.7
# 9      23  64  13  22.2  3.9   8.3  0.475  1.0  2.7  0.349  ...    0.684  1.4
# 10     34   9   0  22.0  3.7   6.6  0.559  0.6  0.9  0.625  ...    0.833  0.7
# ...

# %%
model = KMeans(n_clusters = 100, random_state = 7)
model.fit(df_final)
clusters = model.labels_
print(len(clusters))
# Out:
# 2104

# %%
df_final_full['Cluster'] = clusters
df_final_full[df_final_full['Name'] == 'LeBron James']
# Out:
#                      Team     Season          Name  Age   G  GS    MP    FG  \
# 23    Cleveland Cavaliers  2014-2015  LeBron James   30  69  69  36.1   9.0
# 592   Cleveland Cavaliers  2015-2016  LeBron James   31  76  76  35.6   9.7
# 1118  Cleveland Cavaliers  2016-2017  LeBron James   32  74  74  37.8   9.9
# 1660  Cleveland Cavaliers  2017-2018  LeBron James   33  25  25  37.2  11.0
#
#        FGA    FG%   ...     ORB  DRB  TRB  AST  STL  BLK  TOV   PF  PTS/G  \
# 23    18.5  0.488   ...     0.7  5.3  6.0  7.4  1.6  0.7  3.9  2.0   25.3
# 592   18.6  0.520   ...     1.5  6.0  7.4  6.8  1.4  0.6  3.3  1.9   25.3
# 1118  18.2  0.548   ...     1.3  7.3  8.6  8.7  1.2  0.6  4.1  1.8   26.4
# 1660  18.7  0.587   ...     1.2  6.8  8.0  8.6  1.4  1.2  4.1  1.7   28.2
#
#       Cluster
# 23         29
# 592        84
# 1118       84
# 1660       36
#
# [4 rows x 30 columns]

# %% [markdown]
# Partindo da premissa que LeBron James é um jogador de sucesso, podemos buscar respostas para a seguinte pergunta: quem também é considerado um jogador de sucesso? Isso pode ser respondido, analisando quais jogadores estão no mesmo cluster no mesmo período em que LeBron James esteve no ápice de sua carreira: 2015-2016. Logo, o cluster a ser analisado é o 84.

# %%
df_final_full[df_final_full['Cluster'] == 84]
# Out:
#                         Team     Season               Name  Age   G  GS    MP  \
# 278          Houston Rockets  2014-2015       James Harden   25  81  81  36.8
# 592      Cleveland Cavaliers  2015-2016       LeBron James   31  76  76  35.6
# 610          Toronto Raptors  2015-2016      DeMar DeRozan   26  78  78  35.9
# 831          Houston Rockets  2015-2016       James Harden   26  82  82  38.1
# 850    Golden State Warriors  2015-2016      Stephen Curry   27  79  79  34.2
# 917   Portland Trail Blazers  2015-2016     Damian Lillard   25  75  75  35.7
# 971    Oklahoma City Thunder  2015-2016       Kevin Durant   27  72  72  35.8
# 972    Oklahoma City Thunder  2015-2016  Russell Westbrook   27  80  80  34.4
# 1103          Boston Celtics  2016-2017      Isaiah Thomas   27  76  76  33.8
# 1118     Cleveland Cavaliers  2016-2017       LeBron James   32  74  74  37.8
# 1140         Toronto Raptors  2016-2017      DeMar DeRozan   27  74  74  35.4
# ...

# %% [markdown]
# Vemos, a partir da filtragem realizada, os jogadores que podem ser considerados "bem sucedidos", ao pertencer ao cluster de LeBron James no ápice de sua carreira. O que fica claro, para quem já é familiar com NBA, é que todos os jogadores que aparecem nesse grupo são jogadores conhecidos como bem sucedidos, e que são considerados as estrelas de seus respectivos times, em suas respectivas temporadas. Outra coisa intrigante é que o jogador do GSW, Stephen Curry, aparece apenas uma vez no mesmo cluster que LeBron, o que leva à seguinte pergunta: à que outros grupos Stephen Curry pertenceu?

# %%
df_final_full[df_final_full['Name'] == 'Stephen Curry']
# Out:
#                        Team     Season           Name  Age   G  GS    MP  \
# 298   Golden State Warriors  2014-2015  Stephen Curry   26  80  80  32.7
# 850   Golden State Warriors  2015-2016  Stephen Curry   27  79  79  34.2
# 1392  Golden State Warriors  2016-2017  Stephen Curry   28  79  79  33.4
# 1891  Golden State Warriors  2017-2018  Stephen Curry   29  23  23  32.6
#
#         FG   FGA    FG%   ...     ORB  DRB  TRB  AST  STL  BLK  TOV   PF  \
# 298    8.2  16.8  0.487   ...     0.7  3.6  4.3  7.7  2.0  0.2  3.1  2.0
# 850   10.2  20.2  0.504   ...     0.9  4.6  5.4  6.7  2.1  0.2  3.3  2.0
# 1392   8.5  18.3  0.468   ...     0.8  3.7  4.5  6.6  1.8  0.2  3.0  2.3
# 1891   8.3  17.7  0.473   ...     0.7  4.4  5.1  6.6  1.7  0.2  2.9  2.5
#
#       PTS/G  Cluster
# 298    23.8        4
# 850    30.1       84
# 1392   25.3        4
# 1891   26.3       36
#
# [4 rows x 30 columns]

# %% [markdown]
# Dado que o fato do jogador pertencer ao grupo 36 é irrelevante, pois é um conjunto de dados parcial(dado que a temporada ainda não acabou), analisemos os primeiros 3 grupos aos quais Stephen pertenceu. Stephen pertenceu aos clusters 4 em duas temporadas, e nas mesmas o Golden State Warriors foi campeão. Já na 84, o mesmo esteve no mesmo cluster de LeBron James, como vimos anteriormente, e seu time perdeu para o de LeBron. Outro fato interessante, é que Stephen perdeu na temporada onde mais fez pontos por jogo. Uma possível conclusão dessa análise é que em 2015-2016 Stephen teve mais recurso alocado/o time se baseou e dependeu mais dele, e consequentemente teve a derrota.

# %%
df_final_full[df_final_full['Name'] == 'DeMarcus Cousins']
# Out:
#                       Team     Season              Name  Age   G  GS    MP  \
# 539       Sacramento Kings  2014-2015  DeMarcus Cousins   24  59  59  34.1
# 1073      Sacramento Kings  2015-2016  DeMarcus Cousins   25  65  65  34.6
# 1475  New Orleans Pelicans  2016-2017  DeMarcus Cousins   26  17  17  33.8
# 1602      Sacramento Kings  2016-2017  DeMarcus Cousins   26  55  55  34.4
# 1964  New Orleans Pelicans  2017-2018  DeMarcus Cousins   27  25  25  35.6
#
#        FG   FGA    FG%   ...     ORB   DRB   TRB  AST  STL  BLK  TOV   PF  \
# 539   8.4  18.1  0.467   ...     3.1   9.5  12.7  3.6  1.5  1.7  4.3  4.1
# 1073  9.2  20.5  0.451   ...     2.4   9.1  11.5  3.3  1.6  1.4  3.8  3.6
# 1475  8.4  18.5  0.452   ...     2.2  10.2  12.4  3.9  1.5  1.1  3.6  4.4
# 1602  9.2  20.3  0.452   ...     2.1   8.5  10.6  4.8  1.4  1.3  3.8  3.7
# 1964  8.9  19.3  0.462   ...     2.2  10.5  12.6  5.1  1.6  1.7  5.0  3.5
#
#       PTS/G  Cluster
# 539    24.1       59
# 1073   26.9       59
# ...

# %% [markdown]
# A análise sobre o jogador DeMarcus Cousins é interessante, pois o mesmo troca de time em uma das temporadas e também troca de cluster. Para melhor analisar esse fato, vejamos os dois clusters aos quais ele pertenceu

# %%
df_final_full[df_final_full['Cluster'] == 59]
# Out:
#                        Team     Season               Name  Age   G  GS    MP  \
# 42          Toronto Raptors  2014-2015      DeMar DeRozan   25  60  60  35.0
# 179              Miami Heat  2014-2015        Dwyane Wade   33  62  62  31.8
# 393    New Orleans Pelicans  2014-2015      Anthony Davis   21  68  68  36.1
# 436   Oklahoma City Thunder  2014-2015  Russell Westbrook   26  67  67  34.4
# 457    Los Angeles Clippers  2014-2015      Blake Griffin   25  67  67  35.2
# 539        Sacramento Kings  2014-2015   DeMarcus Cousins   24  59  59  34.1
# 933    New Orleans Pelicans  2015-2016      Anthony Davis   22  61  61  35.5
# 1073       Sacramento Kings  2015-2016   DeMarcus Cousins   25  65  65  34.6
# 1393  Golden State Warriors  2016-2017       Kevin Durant   28  62  62  33.4
# 1534   Los Angeles Clippers  2016-2017      Blake Griffin   27  61  61  34.0
# 1602       Sacramento Kings  2016-2017   DeMarcus Cousins   26  55  55  34.4
#
# ...

# %%
df_final_full[df_final_full['Cluster'] == 36]
# Out:
#                         Team     Season                   Name  Age   G  GS  \
# 437    Oklahoma City Thunder  2014-2015           Kevin Durant   26  27  27
# 1475    New Orleans Pelicans  2016-2017       DeMarcus Cousins   26  17  17
# 1646          Boston Celtics  2017-2018           Kyrie Irving   25  25  25
# 1660     Cleveland Cavaliers  2017-2018           LeBron James   33  25  25
# 1675         Toronto Raptors  2017-2018          DeMar DeRozan   28  22  22
# 1707      Philadelphia 76ers  2017-2018            Joel Embiid   23  20  20
# 1721         Milwaukee Bucks  2017-2018  Giannis Antetokounmpo   23  22  22
# 1738          Indiana Pacers  2017-2018         Victor Oladipo   25  24  24
# 1752      Washington Wizards  2017-2018           Bradley Beal   24  24  24
# 1753      Washington Wizards  2017-2018              John Wall   27  16  16
# 1767         New York Knicks  2017-2018     Kristaps Porzingis   22  20  20
# ...

# %% [markdown]
# Vemos que, enquanto DeMarcus Cousins, durante sua carreira no Sacramento Kings pertence a um cluster com jogadores bem referenciados, como Kevin Durant, Dwyane Wade e Russell Westbrook e apenas jogadores de similar posição na quadra, quando o mesmo vai para o New Orleans Pel
